# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv("Data/df1.csv",index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.shape
# Out:
# (1000, 4)

# %%
df1['A'].plot.hist()

# %%
df1['A'].plot.hist(bins=80,edgecolor='k').autoscale(enable=True,axis='both',tight=True);

# %%
df1['A'].plot.hist(grid=True);

# %%
df2 = pd.read_csv("Data/df2.csv")
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %%
df2.plot.bar();

# %%
df2.plot.bar(stacked=True);

# %%
df2.plot.barh();

# %%
df2.plot.barh(stacked=True);

# %%
df2.plot.line(y='a',figsize=(10,5),lw=4);

# %%
df2.plot.line(y=['a','b','c','d'],figsize=(10,4),lw=3);

# %%
df2.plot.area(stacked=False,alpha=0.4);

# %%
df2.plot.area();

# %%
df2.plot.area(alpha=0.4);

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.scatter(x='A',y='B');

# %%
df1.plot.scatter(x='A',y='C',c='D',cmap='Set2');

# %%
df1.plot.scatter(x='B',y='C',s=df1['A']*36,c='D',cmap='viridis',alpha=0.4);

# %%
df2.plot.box();

# %%
df2['a'].plot.kde();

# %%
df2.plot.kde();

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])
df.head()
# Out:
#           a         b
# 0 -1.180422 -0.077014
# 1  2.630857 -0.663475
# 2  0.021043  0.656518
# 3 -0.342310  0.348751
# 4  1.695608 -0.054416

# %%
df.plot.scatter(x='a',y='b',alpha=0.4);

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coolwarm');
