# %%
import pandas as pd

# %%
df2 = pd.read_csv("Data/df2.csv")
df2.head()
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y

# %%
df2['d'].plot();

# %%
df2['c'].plot.line(figsize=(10,4),ls='-');

# %%
df2['d'].plot.line(figsize=(10,4),ls=':',c='brown',lw=4);

# %%
df2['b'].plot.line(figsize=(10,4),ls='-.');

# %%
ax = df2['d'].plot.line(figsize=(10,4),ls=':',c='brown',lw=4)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('D');

# %%
ax = df2['c'].plot.line(figsize=(10,4),ls='-.',c='crimson',lw=4)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('C');

# %%
# best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center

# %%
ax = df2.plot()
ax.legend(loc='upper right');

# %%
ax = df2.plot()
ax.legend(loc='upper left');

# %%
ax = df2.plot()
ax.legend(loc='lower right');

# %%
ax = df2.plot()
ax.legend(loc='lower left');

# %%
ax = df2.plot()
ax.legend(loc=2,bbox_to_anchor=(1.0,1.0));

# %%
ax = df2.plot()
ax.legend(loc=3,bbox_to_anchor=(1.0,0.5));
