# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Data/airline_passengers.csv',index_col=0,parse_dates=True)
df.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
df.shape
# Out:
# (144, 1)

# %%
df.isna().sum()
# Out:
# Thousands of Passengers    0
# dtype: int64

# %%
df.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
df['6-month SMA'] = df['Thousands of Passengers'].rolling(window=6).mean()
df['12-month SMA'] = df['Thousands of Passengers'].rolling(window=12).mean()

# %%
df.plot(figsize=(12,5));

# %%
df['EWMA-12'] = df['Thousands of Passengers'].ewm(span=12).mean()
df['EWMA-6'] = df['Thousands of Passengers'].ewm(span=6).mean()

# %%
df[['Thousands of Passengers','EWMA-6','EWMA-12','12-month SMA']].plot(figsize=(10,8));

# %%
df[['Thousands of Passengers','EWMA-6','EWMA-12']].plot(figsize=(10,8));
